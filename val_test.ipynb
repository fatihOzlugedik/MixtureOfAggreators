# %%
import pandas as pd
csv_path = "/lustre/groups/labs/marr/qscd01/workspace/fatih.oezluegedik/mixture_of_aggregators/AML_Hehr/summary_global/summary_all_results_metrics_val_and_test.csv"

# Load CSV
df = pd.read_csv(csv_path)

# Sort by validation balanced accuracy mean (descending, best first)
df_sorted = df.sort_values(by="Val_bAcc_mean", ascending=False)

# Save sorted CSV
out_path = csv_path.replace(".csv", "_valBacc_sorted.csv")
df_sorted.to_csv(out_path, index=False)

print(f"Sorted file saved to: {out_path}")
df_sorted.head()
# Out:
# Sorted file saved to: /lustre/groups/labs/marr/qscd01/workspace/fatih.oezluegedik/mixture_of_aggregators/AML_Hehr/summary_global/summary_all_results_metrics_val_and_test_valBacc_sorted.csv
#                                              ResultDir  Val_bAcc_fold0  \
# 218  6_experts/Results_5fold_testfixed_dinobloom-b_...        0.810000
# 247  6_experts/Results_5fold_testfixed_dinobloom-b_...        0.803333
# 163  5_experts/Results_5fold_testfixed_dinobloom-b_...        0.803333
# 66   3_experts/Results_5fold_testfixed_dinobloom-b_...        0.843333
# 253  7_experts/Results_5fold_testfixed_dinobloom-b_...        0.810000
#
#      Val_bAcc_fold1  Val_bAcc_fold2  Val_bAcc_fold3  Val_bAcc_fold4  \
# 218        0.886667        0.966667        0.900000        1.000000
# 247        0.920000        0.966667        0.866667        1.000000
# 163        0.886667        0.966667        0.933333        0.966667
# 66         0.876667        0.966667        0.900000        0.966667
# ...

# %%
# Load CSV
df = pd.read_csv(csv_path)

# Sort by test balanced accuracy mean (descending, best first)
df_sorted = df.sort_values(by="Test_bAcc_mean", ascending=False)

# Save sorted CSV
out_path = csv_path.replace(".csv", "_TestBacc_sorted.csv")
df_sorted.to_csv(out_path, index=False)

print(f"Sorted file saved to: {out_path}")
df_sorted.head()
# Out:
# Sorted file saved to: /lustre/groups/labs/marr/qscd01/workspace/fatih.oezluegedik/mixture_of_aggregators/AML_Hehr/summary_global/summary_all_results_metrics_val_and_test_TestBacc_sorted.csv
#                                              ResultDir  Val_bAcc_fold0  \
# 150  5_experts/Results_5fold_testfixed_dinobloom-b_...        0.843333
# 135  4_experts/Results_5fold_testfixed_dinobloom-b_...        0.770000
# 192  5_experts/Results_5fold_testfixed_dinobloom-b_...        0.770000
# 146  5_experts/Results_5fold_testfixed_dinobloom-b_...        0.803333
# 261  7_experts/Results_5fold_testfixed_dinobloom-b_...        0.770000
#
#      Val_bAcc_fold1  Val_bAcc_fold2  Val_bAcc_fold3  Val_bAcc_fold4  \
# 150        0.926667        0.933333        0.833333        0.966667
# 135        0.886667        0.933333        0.776667        0.926667
# 192        0.886667        0.966667        0.793333        0.966667
# 146        0.880000        0.933333        0.760000        0.966667
# ...
